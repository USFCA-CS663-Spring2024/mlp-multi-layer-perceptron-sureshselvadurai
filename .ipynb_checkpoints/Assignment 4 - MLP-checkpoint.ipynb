# %% [markdown]
# # CS 663 - Machine Learning Spring, 2024
# ## Assignment 04 - MLP (Multi-Layer Perceptron)
#
# ### Goals :
# 1. To build a basic MLP in PyTorch and execute it against a real dataset.
# 2. To tune the MLP to get maximum performance.
# 3. To build a basic MLP from basic Python in order to deepen your understanding of neural networks.

# %% [markdown]
# ### Dataset
#
# - This dataset is related to red variants of the Portuguese "Vinho Verde" wine. For more details, consult the reference Cortez et al., 2009.
# - Ref: [Kaggle](https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009).

# %% [markdown]
# # Import data

# %%
import sys
sys.path.append("./modules")
from eda.eda import EDAAnalyzer
from feature_engineering import FeatureEngineer
from MLP import MLP
from MLP import MLPWrapper
from WineWualityDataLoader.wine_quality_data_loader import WineQualityDataset
import pandas as pd
import seaborn as sns
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn

# %%
df = pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %% [markdown]
# ## EDA

# %%
eda_analyzer = EDAAnalyzer(df)
eda_analyzer.display_shape()
# Out:
# 'Shape of data: rows: 1599 cols: 12'

# %%
eda_analyzer.describe()
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# fixed acidity          7.90000   9.200000   15.90000
# volatile acidity       0.52000   0.640000    1.58000
# citric acid            0.26000   0.420000    1.00000
# residual sugar         2.20000   2.600000   15.50000
# chlorides              0.07900   0.090000    0.61100
# free sulfur dioxide   14.00000  21.000000   72.00000
# total sulfur dioxide  38.00000  62.000000  289.00000
# density                0.99675   0.997835    1.00369
# pH                     3.31000   3.400000    4.01000
# sulphates              0.62000   0.730000    2.00000
# alcohol               10.20000  11.100000   14.90000
# quality                6.00000   6.000000    8.00000

# %%
eda_analyzer.display_column_info()
# Out:
#              Column Name  Non-null Count  Percent Non-null Data Type
# 0          fixed acidity            1599             100.0   float64
# 1       volatile acidity            1599             100.0   float64
# 2            citric acid            1599             100.0   float64
# 3         residual sugar            1599             100.0   float64
# 4              chlorides            1599             100.0   float64
# 5    free sulfur dioxide            1599             100.0   float64
# 6   total sulfur dioxide            1599             100.0   float64
# 7                density            1599             100.0   float64
# 8                     pH            1599             100.0   float64
# 9              sulphates            1599             100.0   float64
# 10               alcohol            1599             100.0   float64
# 11               quality            1599             100.0     int64

# %% [markdown]
# ## Univariate Analysis

# %%
eda_analyzer.plot_histograms()

# %%
eda_analyzer.get_box_plot()

# %%
eda_analyzer.get_skew_kurt()
# Out:
#              Column Name  Skewness   Kurtosis     Category
# 5    free sulfur dioxide  1.250567   2.023562    Inbetween
# 0          fixed acidity  0.982751   1.132143  Normal Data
# 1       volatile acidity  0.671593   1.225542  Normal Data
# 2            citric acid  0.318337   0.788998  Normal Data
# 7                density  0.071288   0.934079  Normal Data
# 8                     pH  0.193683   0.806943  Normal Data
# 10               alcohol  0.860829   0.200029  Normal Data
# 11               quality  0.217802   0.296708  Normal Data
# 3         residual sugar  4.540655  28.617595   Power Data
# 4              chlorides  5.680347  41.715787   Power Data
# 6   total sulfur dioxide  1.515531   3.809824   Power Data
# 9              sulphates  2.428672  11.720251   Power Data

# %% [markdown]
# ## Bivariate Analysis

# %%
eda_analyzer.get_scatter_plot(["quality"])

# %%
eda_analyzer.get_scatter_plot(["quality"],add_trend=True)

# %%
eda_analyzer.get_heat_map()

# %%
eda_analyzer.get_top_correlated_pairs_by_column(column_name="quality")
# Out:
#                 Column 1 Column 2  Correlation Coefficient  \
# 65               alcohol  quality                 0.476166
# 20      volatile acidity  quality                 0.390558
# 64             sulphates  quality                 0.251397
# 29           citric acid  quality                 0.226373
# 55  total sulfur dioxide  quality                 0.185100
# 59               density  quality                 0.174919
# 44             chlorides  quality                 0.128907
# 10         fixed acidity  quality                 0.124052
# 62                    pH  quality                 0.057731
# 50   free sulfur dioxide  quality                 0.050656
#
#    Correlation Category
# 65             Moderate
# 20             Moderate
# 64                  Low
# 29                  Low
# 55                  Low
# 59                  Low
# 44                  Low
# 10                  Low
# 62                  Low
# 50                  Low

# %% [markdown]
# ## Data Quality Report
#
# - **Dataset:** This dataset is related to red variants of the Portuguese "Vinho Verde" wine.
#
# - **Shape of Data:** Rows: 1599, Columns: 12
#
# - **Null Values:** No null values present. The range values of different columns seem appropriate.
#
# - **Column Analysis:**
#     - Columns 'residual sugar' and 'chlorides' have high-powered data shapes, while 'pH' and 'alcohol' exhibit a high normal distribution.
#     - There doesn't appear to be much noise in the data as the columns follow these classifications.
#
# - **Correlation:**
#     - 'Volatile acidity' and 'alcohol' have a high correlation to quality, with minimal spread.
#     - 'Residual sugar' and 'free sulfur dioxide' exhibit high spread out data from the regression line.
#
# - **Input Variables (Based on Physicochemical Tests):**
#     1. Fixed acidity
#     2. Volatile acidity
#     3. Citric acid
#     4. Residual sugar
#     5. Chlorides
#     6. Free sulfur dioxide
#     7. Total sulfur dioxide
#     8. Density
#     9. pH
#     10. Sulphates
#     11. Alcohol
#
# - **Output Variable (Based on Sensory Data):**
#     12. Quality (score between 0 and 10) - The dataset contains quality scores ranging from 3 to 8.

# %% [markdown]
# ## Feature Engineering and train test split

# %%
featureEngineer = FeatureEngineer(df)

# %%
features = ['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']

# %%
featureEngineer.normalize_data(feature_list=features).head(3)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.528360          0.961877    -1.391472       -0.453218  -0.243707
# 1      -0.298547          1.967442    -1.391472        0.043416   0.223875
# 2      -0.298547          1.297065    -1.186070       -0.169427   0.096353
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.466193             -0.379133  0.558274  1.288643  -0.579207
# 1             0.872638              0.624363  0.028261 -0.719933   0.128950
# 2            -0.083669              0.229047  0.134264 -0.331177  -0.048089
#
#     alcohol
# 0 -0.960246
# 1 -0.584777
# 2 -0.584777

# %%
train_x, val_x, test_x, train_y, val_y, test_y = featureEngineer.split_data_test_train_val(features,"quality",test_size=0.15,val_size=0.15)

# %%
train_dataset = WineQualityDataset(train_x, train_y)
val_dataset =  WineQualityDataset(val_x, val_y)
test_dataset =  WineQualityDataset(test_x, test_y)

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64)
test_loader = DataLoader(test_dataset, batch_size=64)

# %% [markdown]
# # Creating a basic MLP

# %% [markdown]
# ### Model config :

# %%
n_inputs=train_x.shape[1]
hidden_size=5
n_outputs=1
activation=nn.ReLU()
learning_rate=0.0001
num_epochs = 50
num_layers=1

# %%
mlp_model = MLP(n_inputs=n_inputs, hidden_size=hidden_size,num_layers=num_layers, n_outputs=n_outputs, activation=activation, learning_rate=learning_rate)

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(mlp_model.parameters(), lr=0.0001)

# %%
mlp_wrapper = MLPWrapper(model=mlp_model, criterion=criterion, optimizer=optimizer)

# %%
train_lossesInit, val_lossesInit = mlp_wrapper.train_validate_curve(train_loader, val_loader, num_epochs=5,print_every=50)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([3])) that is different to the input size (torch.Size([3, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([12])) that is different to the input size (torch.Size([12, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %%
mlp_wrapper.train(train_loader, num_epochs=200)
# Out:
# Final Training Loss: 2.2163213177731165

# %%
test_loss_init = mlp_wrapper.evaluate(test_loader)
print(f"Test Loss: {test_loss_init}")
# Out:
# Test Loss: 2.379756808280945
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([48])) that is different to the input size (torch.Size([48, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %% [markdown]
# # Making changes to basic MLP

# %% [markdown]
# #### Hyperparameter Tuning

# %%
num_epochs_values = [300,500]
learning_rates = [0.001,0.0001]
hidden_sizes = [4,5,6,7]
num_layers_values = [2,3,4,6]
# num_epochs_values = [500]
# learning_rates = [0.0001]
# hidden_sizes = [4]
# num_layers_values = [3]

# %%
best_hyperparameters, best_loss, loss_df = mlp_wrapper.hyperparameter_tuning(train_loader, val_loader, 
                                                          num_epochs_values, learning_rates, 
                                                          hidden_sizes, num_layers_values,print_every=300)
# Out:
# Epoch 300/300, Train Loss: 1.0135396295472194, Val Loss: 1.044442743062973
# Epoch 300/300, Train Loss: 1.159255630091617, Val Loss: 1.0426060259342194
# Epoch 300/300, Train Loss: 1.2693486182313216, Val Loss: 1.2001278549432755
# Epoch 300/300, Train Loss: 1.133800876768012, Val Loss: 1.0572226792573929
# Epoch 300/300, Train Loss: 1.3687634593562077, Val Loss: 1.2523640394210815
# Epoch 300/300, Train Loss: 0.8912401450307745, Val Loss: 0.920310914516449
# Epoch 300/300, Train Loss: 0.8233105791242499, Val Loss: 0.8486892431974411
# Epoch 300/300, Train Loss: 0.8295933165048298, Val Loss: 0.7952979505062103
# Epoch 300/300, Train Loss: 1.0459223938615698, Val Loss: 1.0940285921096802
# Epoch 300/300, Train Loss: 1.0270114133232517, Val Loss: 0.9995934814214706
# Epoch 300/300, Train Loss: 1.2400116732245998, Val Loss: 1.2372073829174042
# Epoch 300/300, Train Loss: 1.1676112193810313, Val Loss: 1.1108555644750595
# Epoch 300/300, Train Loss: 0.9668987456120943, Val Loss: 0.8656343966722488
# Epoch 300/300, Train Loss: 1.1912185392881696, Val Loss: 1.1601841002702713
# Epoch 300/300, Train Loss: 1.7508640163823177, Val Loss: 1.742678850889206
# Epoch 300/300, Train Loss: 1.023495194159056, Val Loss: 1.012524038553238
# Epoch 300/300, Train Loss: 0.7386104103765989, Val Loss: 0.8020531386137009
# Epoch 300/300, Train Loss: 0.7814958691596985, Val Loss: 0.8397401422262192
# Epoch 300/300, Train Loss: 0.8472397954840409, Val Loss: 0.8730944842100143
# Epoch 300/300, Train Loss: 0.723723513515372, Val Loss: 0.7615652084350586
# Epoch 300/300, Train Loss: 0.8035216237369337, Val Loss: 0.8467907309532166
# Epoch 300/300, Train Loss: 1.7122481810419183, Val Loss: 1.8110577464103699
# Epoch 300/300, Train Loss: 1.3407209201862937, Val Loss: 1.2253358662128448
# Epoch 300/300, Train Loss: 1.8295192091088546, Val Loss: 1.958112120628357
# Epoch 300/300, Train Loss: 1.1215098594364368, Val Loss: 1.142790526151657
# Epoch 300/300, Train Loss: 1.1110267576418424, Val Loss: 1.0157906413078308
# Epoch 300/300, Train Loss: 0.9889546993531679, Val Loss: 1.014283537864685
# Epoch 300/300, Train Loss: 1.028637591161226, Val Loss: 1.1008999049663544
# Epoch 300/300, Train Loss: 2.4516799889112773, Val Loss: 2.5643531680107117
# Epoch 300/300, Train Loss: 0.9469331220576638, Val Loss: 0.8981504887342453
# Epoch 300/300, Train Loss: 0.7069219539040014, Val Loss: 0.7533349245786667
# Epoch 300/300, Train Loss: 0.8475670939997623, Val Loss: 0.8702930212020874
# Epoch 300/500, Train Loss: 1.2984052802387036, Val Loss: 1.2311577796936035
# Epoch 300/500, Train Loss: 1.1960277965194301, Val Loss: 1.2303789854049683
# Epoch 300/500, Train Loss: 0.8724546699147475, Val Loss: 0.8711409270763397
# Epoch 300/500, Train Loss: 0.7962727640804491, Val Loss: 0.896262988448143
# Epoch 300/500, Train Loss: 1.1432668551018363, Val Loss: 1.0772000551223755
# Epoch 300/500, Train Loss: 0.8158278198618638, Val Loss: 0.8639684170484543
# Epoch 300/500, Train Loss: 1.046555519104004, Val Loss: 1.097756803035736
# Epoch 300/500, Train Loss: 1.321517172612642, Val Loss: 1.251940280199051
# Epoch 300/500, Train Loss: 1.018642754931199, Val Loss: 0.9870048016309738
# Epoch 300/500, Train Loss: 0.9614715042867159, Val Loss: 0.9820898622274399
# Epoch 300/500, Train Loss: 1.2492617102045762, Val Loss: 1.4016446769237518
# Epoch 300/500, Train Loss: 0.9551062238843817, Val Loss: 0.9610527753829956
# Epoch 300/500, Train Loss: 0.849797459025132, Val Loss: 0.8642527312040329
# Epoch 300/500, Train Loss: 0.8088296683211076, Val Loss: 0.8332026898860931
# Epoch 300/500, Train Loss: 1.012201958581021, Val Loss: 1.0929623246192932
# Epoch 300/500, Train Loss: 0.8953467921206826, Val Loss: 0.9577650874853134
# Epoch 300/500, Train Loss: 1.2219954791821932, Val Loss: 1.0864158868789673
# Epoch 300/500, Train Loss: 1.0579474882075661, Val Loss: 1.165308952331543
# Epoch 300/500, Train Loss: 1.2130831480026245, Val Loss: 1.2174768149852753
# Epoch 300/500, Train Loss: 0.7511379608982488, Val Loss: 0.7927278727293015
# Epoch 300/500, Train Loss: 0.8411757130371896, Val Loss: 0.8991859257221222
# Epoch 300/500, Train Loss: 1.4534699446276615, Val Loss: 1.546745777130127
# Epoch 300/500, Train Loss: 2.1593398232209053, Val Loss: 2.34605872631073
# Epoch 300/500, Train Loss: 1.3027396923617314, Val Loss: 1.3070040345191956
# Epoch 300/500, Train Loss: 0.8425925656368858, Val Loss: 0.8128157556056976
# Epoch 300/500, Train Loss: 1.2798171545329846, Val Loss: 1.2832119464874268
# Epoch 300/500, Train Loss: 1.0141131281852722, Val Loss: 1.148155078291893
# Epoch 300/500, Train Loss: 0.976790748144451, Val Loss: 0.9609980583190918
# Epoch 300/500, Train Loss: 0.9806850207479376, Val Loss: 0.9865869283676147
# Epoch 300/500, Train Loss: 1.3369199664969194, Val Loss: 1.3419575691223145
# Epoch 300/500, Train Loss: 0.6777461500544297, Val Loss: 0.6969317346811295
# Epoch 300/500, Train Loss: 0.7676395366066381, Val Loss: 0.770046278834343

# %%
best_hyperparameters
# Out:
# {'num_epochs': 500, 'learning_rate': 0.0001, 'hidden_size': 7, 'num_layers': 4}

# %%
best_loss
# Out:
# 0.6793293505907059

# %% [markdown]
# ### Track of the changes

# %%
loss_df
# Out:
#     num_epochs  learning_rate  hidden_size  num_layers  val_loss
# 0          300         0.0010            4           2  1.044443
# 1          300         0.0010            4           3  1.042606
# 2          300         0.0010            4           4  1.200128
# 3          300         0.0010            4           6  1.057223
# 4          300         0.0010            5           2  1.252364
# ..         ...            ...          ...         ...       ...
# 59         500         0.0001            6           6  0.802842
# 60         500         0.0001            7           2  0.802850
# 61         500         0.0001            7           3  0.952527
# 62         500         0.0001            7           4  0.679329
# 63         500         0.0001            7           6  0.709081
#
# [64 rows x 5 columns]

# %%
eda_analyzer_loss_df = EDAAnalyzer(loss_df)
eda_analyzer_loss_df.get_scatter_plot(y_cols=["val_loss"],add_trend=True)

# %%
pivot_table = pd.pivot_table(loss_df, values='val_loss', 
                              index=pd.cut(loss_df['num_epochs'], bins=2),
                              columns=[pd.cut(loss_df['learning_rate'], bins=2),
                                       pd.cut(loss_df['hidden_size'], bins=4),
                                       pd.cut(loss_df['num_layers'], bins=4)],
                              aggfunc='mean')

styled_table = pivot_table.style.background_gradient(cmap='coolwarm', axis=None)

styled_table
# Out:
# <style type="text/css">
# #T_27f41_row0_col0 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col1, #T_27f41_row0_col11 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col2, #T_27f41_row1_col14 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_27f41_row0_col4 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_27f41_row0_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col6 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_27f41_row0_col7 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_27f41_row0_col8 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_27f41_row0_col9 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col10 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col12 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_27f41_row0_col13 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_27f41_row0_col14 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_27f41_row0_col15 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_27f41_row0_col16, #T_27f41_row1_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col17 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_27f41_row0_col18 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_27f41_row0_col19 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_27f41_row0_col20 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_27f41_row0_col21, #T_27f41_row0_col23 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_27f41_row0_col22 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col1, #T_27f41_row1_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col2, #T_27f41_row1_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col4 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_27f41_row1_col5, #T_27f41_row1_col17 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col6, #T_27f41_row1_col13 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col8 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col10 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col11 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col12 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col15 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col16 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col18 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col19 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col20, #T_27f41_row1_col22 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col21 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_27f41_row1_col23 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_27f41">
#   <thead>
#     <tr>
#       <th class="index_name level0" >learning_rate</th>
#       <th id="T_27f41_level0_col0" class="col_heading level0 col0" colspan="12">(9.91e-05, 0.00055]</th>
#       <th id="T_27f41_level0_col12" class="col_heading level0 col12" colspan="12">(0.00055, 0.001]</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >hidden_size</th>
#       <th id="T_27f41_level1_col0" class="col_heading level1 col0" colspan="3">(3.997, 4.75]</th>
#       <th id="T_27f41_level1_col3" class="col_heading level1 col3" colspan="3">(4.75, 5.5]</th>
#       <th id="T_27f41_level1_col6" class="col_heading level1 col6" colspan="3">(5.5, 6.25]</th>
#       <th id="T_27f41_level1_col9" class="col_heading level1 col9" colspan="3">(6.25, 7.0]</th>
#       <th id="T_27f41_level1_col12" class="col_heading level1 col12" colspan="3">(3.997, 4.75]</th>
#       <th id="T_27f41_level1_col15" class="col_heading level1 col15" colspan="3">(4.75, 5.5]</th>
#       <th id="T_27f41_level1_col18" class="col_heading level1 col18" colspan="3">(5.5, 6.25]</th>
#       <th id="T_27f41_level1_col21" class="col_heading level1 col21" colspan="3">(6.25, 7.0]</th>
#     </tr>
#     <tr>
#       <th class="index_name level2" >num_layers</th>
#       <th id="T_27f41_level2_col0" class="col_heading level2 col0" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col1" class="col_heading level2 col1" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col2" class="col_heading level2 col2" >(5.0, 6.0]</th>
#       <th id="T_27f41_level2_col3" class="col_heading level2 col3" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col4" class="col_heading level2 col4" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col5" class="col_heading level2 col5" >(5.0, 6.0]</th>
#       <th id="T_27f41_level2_col6" class="col_heading level2 col6" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col7" class="col_heading level2 col7" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col8" class="col_heading level2 col8" >(5.0, 6.0]</th>
#       <th id="T_27f41_level2_col9" class="col_heading level2 col9" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col10" class="col_heading level2 col10" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col11" class="col_heading level2 col11" >(5.0, 6.0]</th>
#       <th id="T_27f41_level2_col12" class="col_heading level2 col12" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col13" class="col_heading level2 col13" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col14" class="col_heading level2 col14" >(5.0, 6.0]</th>
#       <th id="T_27f41_level2_col15" class="col_heading level2 col15" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col16" class="col_heading level2 col16" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col17" class="col_heading level2 col17" >(5.0, 6.0]</th>
#       <th id="T_27f41_level2_col18" class="col_heading level2 col18" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col19" class="col_heading level2 col19" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col20" class="col_heading level2 col20" >(5.0, 6.0]</th>
#       <th id="T_27f41_level2_col21" class="col_heading level2 col21" >(1.996, 3.0]</th>
#       <th id="T_27f41_level2_col22" class="col_heading level2 col22" >(3.0, 4.0]</th>
#       <th id="T_27f41_level2_col23" class="col_heading level2 col23" >(5.0, 6.0]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >num_epochs</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#       <th class="blank col16" >&nbsp;</th>
#       <th class="blank col17" >&nbsp;</th>
#       <th class="blank col18" >&nbsp;</th>
#       <th class="blank col19" >&nbsp;</th>
#       <th class="blank col20" >&nbsp;</th>
#       <th class="blank col21" >&nbsp;</th>
#       <th class="blank col22" >&nbsp;</th>
#       <th class="blank col23" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27f41_level0_row0" class="row_heading level0 row0" >(299.8, 400.0]</th>
#       <td id="T_27f41_row0_col0" class="data row0 col0" >0.820897</td>
#       <td id="T_27f41_row0_col1" class="data row0 col1" >0.873094</td>
#       <td id="T_27f41_row0_col2" class="data row0 col2" >0.761565</td>
#       <td id="T_27f41_row0_col3" class="data row0 col3" >1.328924</td>
#       <td id="T_27f41_row0_col4" class="data row0 col4" >1.225336</td>
#       <td id="T_27f41_row0_col5" class="data row0 col5" >1.958112</td>
#       <td id="T_27f41_row0_col6" class="data row0 col6" >1.079291</td>
#       <td id="T_27f4

# %% [markdown]
# ### Explanation of Performance Changes
#
# - Initially, we conducted a random swarm-like search to explore the dataset.
# - Analysis from the pivot table and plot yields the following insights:
#     1. The proximity of targets suggests that a lower learning rate results in reduced validation loss, indicating that the search for the point of minimal occurrence is smooth.
#     2. Increasing the number of hidden layers enhances performance, suggesting that some features are being effectively engineered. This aligns with the high interdependency among chemical columns.
#     3. Fluctuations in the number of layers indicate the dataset's inability to absorb additional data, likely due to low data count and small bin size.
#     4. The range of epochs demonstrates a trade-off between overfitting and convergence to a minimum, as evidenced by the fluctuating columns. This variability indicates successful selection of an optimal epoch range during the search process.

# %%
mlp_wrapper.set_hyperparameters(**best_hyperparameters)

# %%
mlp_wrapper.train(train_loader, num_epochs=best_hyperparameters['num_epochs'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([3])) that is different to the input size (torch.Size([3, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Final Training Loss: 0.6447994183552893

# %%
test_loss_tuned = mlp_wrapper.evaluate(test_loader)
print("Final Test Loss:", test_loss_tuned)
# Out:
# Final Test Loss: 0.6709625497460365
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([48])) that is different to the input size (torch.Size([48, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)

# %% [markdown]
# ### Performance of Tuned Model
#
# We observed a 70% improvement in the performance of our tuned model compared to our basic MLP. This improvement was achieved through careful tuning, considering the expected behavior of parameters in relation to the dataset and the problem statement.
#
# - Tuning and Reasoning:
#     - Through parameter tuning, we optimized the model's architecture and hyperparameters to better suit the characteristics of the dataset and address the requirements of the problem statement.
#     - We anticipated the behavior of parameters based on the nature of the data and the specific challenges posed by the problem. This informed our decisions during the tuning process, allowing us to make adjustments that significantly enhanced the model's performance.

# %%
percent_change = -((test_loss_tuned - test_loss_init) / test_loss_init) * 100
print("Performance improvement Percent of tuned model in comparison with basic MLP:", round(percent_change,2), "%")
# Out:
# Performance improvement Percent of tuned model in comparison with basic MLP: 71.81 %

# %% [markdown]
# # Optional: Implementing the MLP

# %%
# Add steps
